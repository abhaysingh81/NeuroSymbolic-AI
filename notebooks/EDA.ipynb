# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv("D:/AIMS/Research_Intern/NeuroSymbolicAI/project/data/train.csv")

# Key questions to answer:
print(df['target_name'].unique())       #the 5 biomass components
print(df.groupby('target_name')['target'].describe())  # Distribution per target
print(df[['Pre_GSHH_NDVI','Height_Ave_cm','target']].corr())           # Feature correlations
sns.boxplot(x='target_name', y='target', data=df)     # Spot outliers
# Out:
# ['Dry_Clover_g' 'Dry_Dead_g' 'Dry_Green_g' 'Dry_Total_g' 'GDM_g']
#               count       mean        std   min      25%      50%      75%  \
# target_name
# Dry_Clover_g  357.0   6.649692  12.117761  0.00   0.0000   1.4235   7.2429
# Dry_Dead_g    357.0  12.044548  12.402007  0.00   3.2000   7.9809  17.6378
# Dry_Green_g   357.0  26.624722  25.401232  0.00   8.8000  20.8000  35.0834
# Dry_Total_g   357.0  45.318097  27.984015  1.04  25.2715  40.3000  57.8800
# GDM_g         357.0  33.274414  24.935822  1.04  16.0261  27.1082  43.6757
#
#                    max
# target_name
# Dry_Clover_g   71.7865
# Dry_Dead_g     83.8407
# Dry_Green_g   157.9836
# Dry_Total_g   185.7000
# GDM_g         157.9836
#                Pre_GSHH_NDVI  Height_Ave_cm    target
# Pre_GSHH_NDVI       1.000000       0.238434  0.246426
# Height_Ave_cm       0.238434       1.000000  0.327695
# target              0.246426       0.327695  1.000000
# <Axes: xlabel='target_name', ylabel='target'>
